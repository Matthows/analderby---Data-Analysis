# %% [markdown]
# Define whether a correlation exists between the quantity of home team attendance and the home team score.

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
import pingouin as pg
import matplotlib.pyplot as plt
from scipy.stats import chi2_contingency
plt.style.use('ggplot')
# pd.set_option('max_columns', 200)

# %% [markdown]
# # IMPORT CSV DATASET

# %%
df_games = pd.read_csv('AssignmentData/games.csv')

# %%
df_games.head()
# Out:
#    game_id competition_id  season         round        date  home_club_id  \
# 0  2222597            RU1    2012   6. Matchday  2012-08-25          3725
# 1  2222627            RU1    2012   5. Matchday  2012-08-20          2696
# 2  2222658            RU1    2012  10. Matchday  2012-09-30          2410
# 3  2222664            RU1    2012   8. Matchday  2012-09-15           932
# 4  2222683            RU1    2012  12. Matchday  2012-10-22          2696
#
#    away_club_id  home_club_goals  away_club_goals  home_club_position  ...  \
# 0           232                2                1                 2.0  ...
# 1          4128                0                2                11.0  ...
# 2           121                0                2                 2.0  ...
# 3          2698                1                0                 5.0  ...
# 4         12438                0                1                11.0  ...
#
#         stadium attendance               referee  \
# 0  Akhmat-Arena    21700.0  Vladislav Bezborodov
# 1     Metallurg    11400.0         Sergey Ivanov
# 2  Arena Khimki    12000.0        Sergey Karasev
# 3     RZD Arena    11408.0        Sergey Karasev
# 4     Metallurg     7534.0     Timur Arslanbekov
#
#                                                  url  home_club_formation  \
# 0  https://www.transfermarkt.co.uk/terek-grozny_s...                  NaN
# 1  https://www.transfermarkt.co.uk/krylya-sovetov...                  NaN
# 2  https://www.transfermarkt.co.uk/cska-moscow_di...                  NaN
# 3  https://www.transfermarkt.co.uk/lokomotiv-mosc...                  NaN
# 4  https://www.transfermarkt.co.uk/krylya-sovetov...                  NaN
#
#   away_club_formation                      home_club_name  \
# 0                 NaN                   RFK Akhmat Grozny
# 1                 NaN           PFK Krylya Sovetov Samara
# 2                 NaN                     PFK CSKA Moskva
# 3                 NaN  Футбольный клуб "Локомотив" Москва
# 4                 NaN           PFK Krylya Sovetov Samara
#
#                     away_club_name aggregate competition_type
# 0                FK Spartak Moskva       2:1  domestic_league
# 1                       Amkar Perm       0:2  domestic_league
# 2                 FK Dinamo Moskva       0:2  domestic_league
# 3                   FC Rubin Kazan       1:0  domestic_league
# 4  Volga Nizhniy Novgorod (- 2016)       0:1  domestic_league
#
# [5 rows x 23 columns]

# %%
df_games.columns
# Out:
# Index(['game_id', 'competition_id', 'season', 'round', 'date', 'home_club_id',
#        'away_club_id', 'home_club_goals', 'away_club_goals',
#        'home_club_position', 'away_club_position', 'home_club_manager_name',
#        'away_club_manager_name', 'stadium', 'attendance', 'referee', 'url',
#        'home_club_formation', 'away_club_formation', 'home_club_name',
#        'away_club_name', 'aggregate', 'competition_type'],
#       dtype='object')

# %% [markdown]
# ### Select usefull columns only
# Clean useless columns

# %%
df_games_cleaned = df_games[[
    'game_id', 'competition_id', 'season', 'round', 'date', 'home_club_id',
       'away_club_id', 'home_club_goals', 'away_club_goals',
       'home_club_position', 'away_club_position', 'stadium', 'attendance', 'home_club_name',
       'away_club_name', 'aggregate', 'competition_type'
]].copy()

# %%
df_games_cleaned.head()
# Out:
#    game_id competition_id  season         round        date  home_club_id  \
# 0  2222597            RU1    2012   6. Matchday  2012-08-25          3725
# 1  2222627            RU1    2012   5. Matchday  2012-08-20          2696
# 2  2222658            RU1    2012  10. Matchday  2012-09-30          2410
# 3  2222664            RU1    2012   8. Matchday  2012-09-15           932
# 4  2222683            RU1    2012  12. Matchday  2012-10-22          2696
#
#    away_club_id  home_club_goals  away_club_goals  home_club_position  \
# 0           232                2                1                 2.0
# 1          4128                0                2                11.0
# 2           121                0                2                 2.0
# 3          2698                1                0                 5.0
# 4         12438                0                1                11.0
#
#    away_club_position       stadium  attendance  \
# 0                 5.0  Akhmat-Arena     21700.0
# 1                10.0     Metallurg     11400.0
# 2                13.0  Arena Khimki     12000.0
# 3                 8.0     RZD Arena     11408.0
# 4                16.0     Metallurg      7534.0
#
#                        home_club_name                   away_club_name  \
# 0                   RFK Akhmat Grozny                FK Spartak Moskva
# 1           PFK Krylya Sovetov Samara                       Amkar Perm
# 2                     PFK CSKA Moskva                 FK Dinamo Moskva
# 3  Футбольный клуб "Локомотив" Москва                   FC Rubin Kazan
# 4           PFK Krylya Sovetov Samara  Volga Nizhniy Novgorod (- 2016)
#
#   aggregate competition_type
# 0       2:1  domestic_league
# 1       0:2  domestic_league
# 2       0:2  domestic_league
# 3       1:0  domestic_league
# 4       0:1  domestic_league

# %% [markdown]
# ### Select the most frequent team in games dataset

# %%
counts = df_games_cleaned['home_club_id'].value_counts()
# Find the most frequent value
most_frequent = counts.idxmax()
# Filter the DataFrame to select rows with the most frequent value
most_frequent_row = df_games_cleaned[df_games_cleaned['home_club_id'] == most_frequent]

# %%
most_frequent_row
# Out:
#        game_id competition_id  season          round        date  \
# 1374   2243042            ES1    2012   14. Matchday  2012-12-01
# 1409   2341054            ES1    2013   18. Matchday  2014-01-06
# 1444   2481145            SUC    2014  final 1st leg  2014-08-19
# 1492   2618536             CL    2015        Group A  2015-09-15
# 1538   2878317            SUC    2017  final 2nd leg  2017-08-16
# ...        ...            ...     ...            ...         ...
# 63264  4113073            ES1    2023    7. Matchday  2023-09-27
# 63297  4001330            SUC    2023          Final  2023-01-15
# 63316  3998376            SUC    2023    Semi-Finals  2023-01-11
# 64950  2594621            ES1    2015   16. Matchday  2015-12-20
# 64951  2594631            ES1    2015   17. Matchday  2015-12-30
#
#        home_club_id  away_club_id  home_club_goals  away_club_goals  \
# 1374            418            13                2                0
# 1409            418           940                3                0
# 1444            418            13                1                1
# 1492            418           660                4                0
# 1538            418           131                2                0
# ...             ...           ...              ...              ...
# 63264           418           472                2                0
# 63297           418           131                1                3
# 63316           418          1049                5                4
# 64950           418           367               10                2
# 64951           418           681                3                1
#
#        home_club_position  away_club_position  \
# 1374                  3.0                 2.0
# 1409                  3.0                18.0
# 1444                  NaN                 NaN
# 1492                  NaN                 NaN
# 1538                  NaN                 NaN
# ...                   ...                 ...
# 63264                 2.0                18.0
# 63297                 NaN                 NaN
# 63316                 NaN                 NaN
# 64950                 3.0                18.0
# 64951                 3.0                15.0
#
#                                stadium  attendance  \
# 1374                 Santiago Bernabéu     79000.0
# 1409                 Santiago Bernabéu     65217.0
# 1444                 Santiago Bernabéu     75897.0
# 1492                 Santiago Bernabéu     66389.0
# 1538                 Santiago Bernabéu     70000.0
# ...                                ...         ...
# 63264                Santiago Bernabéu     65017.0
# 63297  King Fahd International Stadium     68752.0
# 63316  King Fahd International Stadium     50492.0
# 64950                Santiago Bernabéu     61564.0
# 64951                Santiago Bernabéu     60907.0
#
#                    home_club_name                     away_club_name  \
# 1374   Real Madrid Club de Fútbol     Club Atlético de Madrid S.A.D.
# 1409   Real Madrid Club de Fútbol   Real Club Celta de Vigo S. A. D.
# 1444   Real Madrid Club de Fútbol     Club Atlético de Madrid S.A.D.
# 1492   Real Madrid Club de Fútbol                FC Shakhtar Donetsk
# 1538   Real Madrid Club de Fútbol              Futbol Club Barcelona
# ...                           ...                                ...
# 63264  Real Madrid Club de Fútbol  Unión Deportiva Las Palmas S.A.D.
# 63297  Real Madrid Club de Fútbol              Futbol Club Barcelona
# 63316  Real Madrid Club de Fútbol   Valencia Club de Fútbol S. A. D.
# 64950  Real Madrid Club de Fútbol    Rayo Vallecano de Madrid S.A.D.
# 64951  Real Madrid Club de Fútbol     Real Sociedad de Fútbol S.A.D.
#
#       aggregate   competition_type
# 1374        2:0    domestic_league
# 1409        3:0    domestic_league
# 1444        1:1              other
# 1492        4:0  international_cup
# 1538        2:0              other
# ...         ...                ...
# 63264       2:0    domestic_league
# 63297       1:3              other
# 63316       5:4              other
# 64950      10:2    domestic_league
# 64951       3:1    domestic_league
#
# [317 rows x 17 columns]

# %%
df_games_cleaned
# Out:
#        game_id competition_id  season                     round        date  \
# 0      2222597            RU1    2012               6. Matchday  2012-08-25
# 1      2222627            RU1    2012               5. Matchday  2012-08-20
# 2      2222658            RU1    2012              10. Matchday  2012-09-30
# 3      2222664            RU1    2012               8. Matchday  2012-09-15
# 4      2222683            RU1    2012              12. Matchday  2012-10-22
# ...        ...            ...     ...                       ...         ...
# 65211  2367292             EL    2013                   Group B  2013-11-07
# 65212  2629035            NLP    2015               Third Round  2015-10-27
# 65213  3092951            CLQ    2018  Qualifying Round 2nd leg  2018-08-29
# 65214  4164101            CGB    2023              Second Round  2023-08-29
# 65215  4013659            FAC    2022              Fourth Round  2023-01-29
#
#        home_club_id  away_club_id  home_club_goals  away_club_goals  \
# 0              3725           232                2                1
# 1              2696          4128                0                2
# 2              2410           121                0                2
# 3               932          2698                1                0
# 4              2696         12438                0                1
# ...             ...           ...              ...              ...
# 65211           383           419                2                0
# 65212           383         16866                6                0
# 65213           383           713                3                0
# 65214           512          1194                6                1
# 65215           512          3684                3                1
#
#        home_club_position  away_club_position          stadium  attendance  \
# 0                     2.0                 5.0     Akhmat-Arena     21700.0
# 1                    11.0                10.0        Metallurg     11400.0
# 2                     2.0                13.0     Arena Khimki     12000.0
# 3                     5.0                 8.0        RZD Arena     11408.0
# 4                    11.0                16.0        Metallurg      7534.0
# ...                   ...                 ...              ...         ...
# 65211                 NaN                 NaN  Philips Stadion     10000.0
# 65212                 NaN                 NaN  Philips Stadion     31000.0
# 65213                 NaN                 NaN  Philips Stadion     34200.0
# 65214                 NaN                 NaN   bet365 Stadium      9410.0
# 65215                 NaN                 NaN   bet365 Stadium     14392.0
#
#                                           home_club_name  \
# 0                                      RFK Akhmat Grozny
# 1                              PFK Krylya Sovetov Samara
# 2                                        PFK CSKA Moskva
# 3                     Футбольный клуб "Локомотив" Москва
# 4                              PFK Krylya Sovetov Samara
# ...                                                  ...
# 65211  Eindhovense Voetbalvereniging Philips Sport Ve...
# 65212  Eindhovense Voetbalvereniging Philips Sport Ve...
# 65213  Eindhovense Voetbalvereniging Philips Sport Ve...
# 65214                                         Stoke City
# 65215                                         Stoke City
#
#                         away_club_name aggregate   competition_type
# 0                    FK Spartak Moskva       2:1    domestic_league
# 1                           Amkar Perm       0:2    domestic_league
# 2                     FK Dinamo Moskva       0:2    domestic_league
# 3                       FC Rubin Kazan       1:0    domestic_league
# 4      Volga Nizhniy Novgorod (- 2016)       0:1    domestic_league
# ...                                ...       ...                ...
# 65211                              NaN       2:0  international_cup
# 65212                              NaN       6:0       domestic_cup
# 65213                              NaN       3:0  international_cup
# 65214                              NaN       6:1              other
# 65215                              NaN       3:1       domestic_cup
#
# [65216 rows x 17 columns]

# %% [markdown]
# ### Estimate the quantity of the home team attendance
# The percentage of available seats for away fans are defined by insitutions like UEFA or Premier League.
# That is around the 10% of the total stadium capability.

# %%
away_attendance_percentage = 0.10 # 10% of attendance
df_games_cleaned['home_team_attendance'] = df_games_cleaned['attendance'] * ( 1 - away_attendance_percentage )

# %% [markdown]
# ### Calculate the average of attendance of home team

# %%
mean_home_team_attendance = df_games_cleaned['home_team_attendance'].median()
print('mean_home_team_attendance = \"' + str(mean_home_team_attendance) + '\"')
# Out:
# mean_home_team_attendance = "10926.0"

# %% [markdown]
# ### Calculate the deviation from the mean for each value

# %%
df_games_cleaned.loc[:, 'deviation_from_median'] = df_games_cleaned['home_team_attendance'] - mean_home_team_attendance

# %% [markdown]
# ### Calculate the mean of the deviation to set a significant thresholds

# %%
df_games_cleaned['deviation_from_median'].mean()
# Out:
# 5328.303602972857

# %% [markdown]
# ### Define thresholds and categorize values

# %%
# Define bins and labels based on deviation from the median
bins = [float('-inf'), -10000, -5000, 0, 5000, 10000, 15000, 20000, 25000, 30000, 35000, 40000, 45000, 50000, float('inf')]
labels = ['T0', 'T1', 'T2', 'T3', 'T4', 'T5', 'T6', 'T7', 'T8', 'T9', 'T10', 'T11', 'T12', 'T13']

# Categorize based on deviation from median
df_games_cleaned['home_team_attendance_category'] = pd.cut(df_games_cleaned['deviation_from_median'], bins=bins, labels=labels)
df_games_cleaned
# Out:
#        game_id competition_id  season                     round        date  \
# 0      2222597            RU1    2012               6. Matchday  2012-08-25
# 1      2222627            RU1    2012               5. Matchday  2012-08-20
# 2      2222658            RU1    2012              10. Matchday  2012-09-30
# 3      2222664            RU1    2012               8. Matchday  2012-09-15
# 4      2222683            RU1    2012              12. Matchday  2012-10-22
# ...        ...            ...     ...                       ...         ...
# 65211  2367292             EL    2013                   Group B  2013-11-07
# 65212  2629035            NLP    2015               Third Round  2015-10-27
# 65213  3092951            CLQ    2018  Qualifying Round 2nd leg  2018-08-29
# 65214  4164101            CGB    2023              Second Round  2023-08-29
# 65215  4013659            FAC    2022              Fourth Round  2023-01-29
#
#        home_club_id  away_club_id  home_club_goals  away_club_goals  \
# 0              3725           232                2                1
# 1              2696          4128                0                2
# 2              2410           121                0                2
# 3               932          2698                1                0
# 4              2696         12438                0                1
# ...             ...           ...              ...              ...
# 65211           383           419                2                0
# 65212           383         16866                6                0
# 65213           383           713                3                0
# 65214           512          1194                6                1
# 65215           512          3684                3                1
#
#        home_club_position  away_club_position          stadium  attendance  \
# 0                     2.0                 5.0     Akhmat-Arena     21700.0
# 1                    11.0                10.0        Metallurg     11400.0
# 2                     2.0                13.0     Arena Khimki     12000.0
# 3                     5.0                 8.0        RZD Arena     11408.0
# 4                    11.0                16.0        Metallurg      7534.0
# ...                   ...                 ...              ...         ...
# 65211                 NaN                 NaN  Philips Stadion     10000.0
# 65212                 NaN                 NaN  Philips Stadion     31000.0
# 65213                 NaN                 NaN  Philips Stadion     34200.0
# 65214                 NaN                 NaN   bet365 Stadium      9410.0
# 65215                 NaN                 NaN   bet365 Stadium     14392.0
#
#                                           home_club_name  \
# 0                                      RFK Akhmat Grozny
# 1                              PFK Krylya Sovetov Samara
# 2                                        PFK CSKA Moskva
# 3                     Футбольный клуб "Локомотив" Москва
# 4                              PFK Krylya Sovetov Samara
# ...                                                  ...
# 65211  Eindhovense Voetbalvereniging Philips Sport Ve...
# 65212  Eindhovense Voetbalvereniging Philips Sport Ve...
# 65213  Eindhovense Voetbalvereniging Philips Sport Ve...
# 65214                                         Stoke City
# 65215                                         Stoke City
#
#                         away_club_name aggregate   competition_type  \
# 0                    FK Spartak Moskva       2:1    domestic_league
# 1                           Amkar Perm       0:2    domestic_league
# 2                     FK Dinamo Moskva       0:2    domestic_league
# 3                       FC Rubin Kazan       1:0    domestic_league
# 4      Volga Nizhniy Novgorod (- 2016)       0:1    domestic_league
# ...                                ...       ...                ...
# 65211                              NaN       2:0  international_cup
# 65212                              NaN       6:0       domestic_cup
# 65213                              NaN       3:0  international_cup
# 65214                              NaN       6:1              other
# 65215                              NaN       3:1       domestic_cup
#
#        home_team_attendance  deviation_from_median  \
# 0                   19530.0                 8604.0
# 1                   10260.0                 -666.0
# 2                   10800.0                 -126.0
# 3                   10267.2                 -658.8
# 4                    6780.6                -4145.4
# ...                     ...                    ...
# 65211                9000.0                -1926.0
# 65212               27900.0                16974.0
# 65213               30780.0                19854.0
# 65214                8469.0                -2457.0
# 65215               12952.8                 2026.8
#
#       home_team_attendance_category
# 0                                T4
# 1                                T2
# 2                                T2
# 3                                T2
# 4                                T2
# ...                             ...
# 65211                            T2
# 65212                            T6
# 65213                            T6
# 65214                            T2
# 65215                            T3
#
# [65216 rows x 20 columns]

# %% [markdown]
# ### Extract Goals from 'aggregate' Column

# %%
df_games_cleaned[['home_goals', 'away_goals']] = df_games_cleaned['aggregate'].str.split(':', expand=True).astype(int)

# %% [markdown]
# ### Calculate the Mean for each group

# %%
# Group by the attendance category and calculate the mean home goals for each category
category_means = df_games_cleaned.groupby('home_team_attendance_category', observed=True)['home_goals'].mean().reset_index()
category_means.columns = ['home_team_attendance_category', 'mean_home_goals']
print(category_means)
# Out:
#    home_team_attendance_category  mean_home_goals
# 0                             T0         1.422026
# 1                             T1         1.383363
# 2                             T2         1.438980
# 3                             T3         1.466297
# 4                             T4         1.483996
# 5                             T5         1.513108
# 6                             T6         1.643615
# 7                             T7         1.714857
# 8                             T8         1.802900
# 9                             T9         1.844523
# 10                           T10         1.958366
# 11                           T11         1.864058
# 12                           T12         1.792994
# 13                           T13         2.165644

# %% [markdown]
# ### Calculate the Correlation Coefficient
# Calculate the Pearson correlation coefficient between 'deviation_from_median' and 'home_goals'

# %%
correlation_coef = np.corrcoef(category_means['mean_home_goals'], df_games_cleaned.groupby('home_team_attendance_category', observed=True)['deviation_from_median'].mean())[0, 1]
print('Correlation Coefficient:', correlation_coef)
# Out:
# Correlation Coefficient: 0.9518760998333287

# %% [markdown]
# ### Scatter Plot with Means

# %%
# Approximate the correlation coefficient value
correlation_text = f'Correlation Coefficient: {correlation_coef:.2f}'

# Scatter plot of deviation from median vs mean home goals
plt.figure(figsize=(12, 6))
plt.scatter(category_means['home_team_attendance_category'], category_means['mean_home_goals'], alpha=0.75, color='b')
plt.title('Scatter plot of Deviation from Median vs Mean Home Goals\n')
plt.xlabel('\nAttendance Category')
plt.ylabel('Mean Home Goals\n')
plt.xticks(rotation=45)
plt.grid(True)


# Annotate the plot with correlation coefficient
plt.annotate(correlation_text, xy=(0.05, 0.95), xycoords='axes fraction', fontsize=12, ha='left', va='top', bbox=dict(boxstyle='round,pad=0.5', fc='white', alpha=0.5))

plt.show()

# %%
sns.boxplot(x='home_goals', y='deviation_from_median', data=df_games_cleaned)
plt.title('Boxplot of Deviation from Mean vs Home Goals')
plt.xlabel('Home Goals')
plt.ylabel('Deviation from Median')
plt.show()

# %%
df_games_cleaned['home_team_attendance_category'].value_counts().sort_index().plot(kind='bar')
plt.title('Histogram of Attendance Categories')
plt.xlabel('Attendance Category')
plt.ylabel('Frequency')
plt.show()
